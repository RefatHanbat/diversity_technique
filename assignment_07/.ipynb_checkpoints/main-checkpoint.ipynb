# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1000

# %%
ip = np.random.rand(N) > 0.5
ip = ip.astype(int)

# %%
Es = 1

# %%
eb_no_db = np.arange(0,25)

# %%
RxMF_capacity = np.zeros(len(eb_no_db))
RxZF_capacity = np.zeros(len(eb_no_db))
RxMMSE_capacity = np.zeros(len(eb_no_db))
RxMF_R_SVD_capacity = np.zeros(len(eb_no_db))
RxZF_R_SVD_capacity = np.zeros(len(eb_no_db))
RxMMSE_R_SVD_capacity = np.zeros(len(eb_no_db))
jointSvdWithCsit = np.zeros(len(eb_no_db))

# %%
def calculate_capacity(nTx,nRx,Rz_inverse):
    
    total_capacity = 0
    
    for ii in range(N):

        H = (1/np.sqrt(2)) * (np.random.randn(nTx,nRx) + 1j * np.random.randn(nTx,nRx))

        H_hermitian = np.conjugate(H)

        H_hermitian = np.transpose(H_hermitian)

        Ns = 4

        
                        

        P = np.sqrt(Es / Ns) * np.block([
                   [np.eye(Ns), np.zeros((Ns, nTx - Ns))],
                   [np.zeros((nTx - Ns, nTx))]
                    ])

        P_hermitian = np.conjugate(P)

        P_hermitian = np.transpose(P_hermitian)

        X = np.eye(4)

        Y = P_hermitian @ H_hermitian @ Rz_inverse @ H @ P

        Z = X + Y

        Z = np.linalg.det(Z)

        c = np.log2(np.abs(Z))
        
        total_capacity = total_capacity + c 
        
    return total_capacity

# %%
def Rx_MF ():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        noise_variance = (1/snr)
        
        nTx = 4
        
        nRx = 4
        
        Rz = noise_variance * np.eye(nRx)
        
        Rz_inverse = np.linalg.inv(Rz)
        
        capacity = calculate_capacity(nTx,nRx,Rz_inverse)
        
        capacity = capacity / N
        
        RxZF_capacity[jj] = capacity
        
    return RxZF_capacity

# %%
def Rx_ZF ():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        noise_variance = (1/snr)
        
        nTx = 4
        
        nRx = 4
        
        Rz = noise_variance * np.eye(nRx)
        
        Rz_inverse = np.linalg.inv(Rz)
        
        capacity = calculate_capacity(nTx,nRx,Rz_inverse)
        
        capacity = capacity / N
        
        RxMF_capacity[jj] = capacity
        
    return RxMF_capacity

# %%
def Rx_MMSE ():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        noise_variance = (1/snr)
        
        nTx = 4
        
        nRx = 4
        
        Rz = noise_variance * np.eye(nRx)
        
        Rz_inverse = np.linalg.inv(Rz)
        
        capacity = calculate_capacity(nTx,nRx,Rz_inverse)
        
        capacity = capacity / N
        
        
        RxMMSE_capacity[jj] = capacity
        
    return RxMMSE_capacity

# %%
def sigma_four(noise_variance,S1,S2,S3,S4,q_optimal_3):
    
    S = [S1, S2, S3, S4]
    
    q_optimal_3 = q_optimal_3
    
    sigma_four_q = []
    
    summation_part = 0
    
    for kk in range(len(S)):
        
        summation_part = summation_part + (noise_variance/np.square(S[kk]))
        
    mu = (1/len(S)) * (Es + summation_part)
    
    for mm in range(len(S)):
        
        qi = mu - (noise_variance/np.square(S[mm]))
        
        if(qi > 0 ):
            
            sigma_four_q.append(qi)
            
        else:
            sigma_four_q = []
            
            sigma_four_q = q_optimal_3.copy()
            
            break
            
    return sigma_four_q

# %%
def sigma_three(noise_variance,S1,S2,S3,q_optimal_2):
    
    S = [S1, S2, S3]
    
    q_optimal_2 = q_optimal_2
    
    sigma_three_q = []
    
    summation_part = 0
    
    for kk in range(len(S)):
        
        summation_part = summation_part + (noise_variance/np.square(S[kk]))
        
    mu = (1/len(S)) * (Es + summation_part)
    
    for mm in range(len(S)):
        
        qi = mu - (noise_variance/np.square(S[mm]))
        
        if(qi > 0 ):
            
            sigma_three_q.append(qi)
            
        else:
            sigma_three_q = []
            
            sigma_three_q = q_optimal_2.copy() 
            
            break
            
    return sigma_three_q

# %%
def sigma_two(noise_variance,S1,S2,q_optimal_1):
    
    S = [ S1 , S2 ]
    
    q_optimal_1 = q_optimal_1

    sigma_two_q  = []
    
    summation_part = 0
    
    for kk in range(len(S)):
        
        summation_part = summation_part +  (noise_variance/np.square(S[kk]))
        
    mu = (1/len(S))* (Es + summation_part)
    
    for mm in range(len(S)):
        
        qi = mu - (noise_variance/np.square(S[mm]))
        
        if(qi > 0):
            
            sigma_two_q.append(qi)
            
        else:
            sigma_two_q = []
            
            sigma_two_q = q_optimal_1.copy()
            
            break
            
    return sigma_two_q

# %%
def sigma_one(noise_variance,S1):
    
    
    S = [S1]
    
    
    sigma_one_q = []
    
    summation_part = noise_variance / np.square(S1)
    
    mu = (1/len(S)) * (Es + summation_part )
    
    q_optimal = mu - (noise_variance / np.square(S1))
    
    if q_optimal > 0 :
        
        sigma_one_q.append(q_optimal)
        
    
    
    return sigma_one_q

# %%
def diagonalQ(S,noise_variance):
    
    
    S1 = S[0]
    
    S2 = S[1]
    
    S3 = S[2]
    
    S4 = S[3]
    
    S = [S1, S2, S3, S4]
    
    q_optimal_1 = sigma_one(noise_variance,S1)
    
    q_optimal_2 = sigma_two(noise_variance,S1,S2,q_optimal_1)
    
    q_optimal_3 = sigma_three(noise_variance,S1,S2,S3,q_optimal_2)
    
    q_optimal_4 = sigma_four(noise_variance,S1,S2,S3,S4,q_optimal_3)
    
    return q_optimal_4

# %%
def calculate_capacity_R_svd(nTx,nRx,Rz_inverse,noise_variance):
    
    total_capacity = 0
    
    for ii in range(N):
        
        H = (1/np.sqrt(2)) * (np.random.randn(nTx,nRx) + 1j * np.random.randn(nTx,nRx))
        
        H_hermitian = np.conjugate(H)
        
        H_hermitian = np.transpose(H_hermitian)
        
        U,S,Vh = np.linalg.svd(H,full_matrices=False)
        
        V = np.conjugate(Vh)
        
        V = np.transpose(V)
        
        Q = diagonalQ(S,noise_variance)
        
        Ns = len(Q)
        
        q_sqrt = np.sqrt(Q)
        
        q_sqrt = q_sqrt[:4]
        
        q_sqrt = np.pad(q_sqrt, (0, 4 - len(q_sqrt)), mode='constant', constant_values=0)
        
        Q_matrix = np.diag(q_sqrt)
        
        P = V[:,0:Ns] @ Q_matrix[0:Ns,0:Ns]
        
        P_hermitian = np.conjugate(P)
        
        P_hermitian = np.transpose(P_hermitian)
        
        Z = np.eye(Ns) + P_hermitian @ H_hermitian @ Rz_inverse @ H @ P
        
        Z = np.linalg.det(Z)

        c = np.log2(np.abs(Z))
        
        total_capacity = total_capacity + c
        
    return total_capacity

# %%
def RxMF_R_SVD():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        Es = 1
        
        noise_variance = (1/snr)
        
        Rz = noise_variance * np.eye(4)
        
        Rz_inverse = np.linalg.inv(Rz)
        
        nTx = 4 
        
        nRx = 4
        
        capacity = calculate_capacity_R_svd(nTx,nRx,Rz_inverse,noise_variance)
        
        RxMF_R_SVD_capacity[jj] = capacity / N
        
    return RxMF_R_SVD_capacity

# %%
def RxZF_R_SVD():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        Es = 1
        
        noise_variance = (1/snr)
        
        Rz = noise_variance * np.eye(4)
        
        Rz_inverse = np.linalg.inv(Rz)
        
        nTx = 4 
        
        nRx = 4
        
        capacity = calculate_capacity_R_svd(nTx,nRx,Rz_inverse,noise_variance)
        
        RxZF_R_SVD_capacity[jj] = capacity / N
        
    return RxZF_R_SVD_capacity

# %%
def RxMMSE_R_SVD():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        Es = 1
        
        noise_variance = (1/snr)
        
        Rz = noise_variance * np.eye(4)
        
        Rz_inverse = np.linalg.inv(Rz)
        
        nTx = 4 
        
        nRx = 4
        
        capacity = calculate_capacity_R_svd(nTx,nRx,Rz_inverse,noise_variance)
        
        RxMMSE_R_SVD_capacity[jj] = capacity / N
        
    return RxMMSE_R_SVD_capacity

# %%
# def calculate_capacity_joint_svd(nTx,nRx,noise_variance,Rz):
    
#     total_capacity = 0
    
#     for ii in range(N):
        
#         H = (1/np.sqrt(2)) * (np.random.randn(nTx,nRx) + 1j * np.random.randn(nTx,nRx))
        
#         H_hermitian = np.conjugate(H)
        
#         H_hermitian = np.transpose(H_hermitian)
        
#         U,S,Vh = np.linalg.svd(H,full_matrices=False)
        
#         V = np.conjugate(Vh)
        
#         V = np.transpose(V)
        
#         U_hermitian = np.conjugate(U)
        
#         U_hermitian = np.transpose(U_hermitian)
        
#         Q = diagonalQ(S,noise_variance)
        
#         Ns = len(S)
        
#         q_sqrt = np.sqrt(Q)
        
#         q_sqrt = q_sqrt[:4]
        
#         q_sqrt = np.pad(q_sqrt, (0, 4 - len(q_sqrt)), mode='constant', constant_values=0)
        
#         Q_matrix = np.diag(q_sqrt)
        
#         P = V @ Q_matrix
        
#         P_hermitian = np.conjugate(P)
        
#         P_hermitian = np.transpose(P_hermitian)
        
#         W = U_hermitian
        
#         W_hermitian = np.conjugate(W)
        
#         W_hermitian = np.transpose(W_hermitian)
        
#         Z = np.linalg.inv(W @ Rz @ W_hermitian)
        
#         Z = Z + W @ H @ P @ P_hermitian @ H_hermitian @ W_hermitian
        
#         Z = np.eye(4) + Z
        
#         Z = np.linalg.det(Z)
        
#         c = np.log2(np.abs(Z))
        
#         total_capacity = total_capacity + c
                    
    
#     return total_capacity

# %%
# def joint_svd_with_csit():
    
#     for jj in range(len(eb_no_db)):
        
#         snr = 10**(eb_no_db[jj] / 10)
        
#         Es = 1
        
#         noise_variance = (1/snr)
        
#         nTx = 4
        
#         nRx = 4
        
#         Rz = noise_variance * np.eye(nRx)
        
#         capacity = calculate_capacity_joint_svd(nTx,nRx,noise_variance,Rz)
        
#         jointSvdWithCsit[jj] = capacity / N
        
#     return jointSvdWithCsit

# %%
def capacity(noise_variance,S):
    
    S1 = S[0]
    
    S2 = S[1]
    
    S3 = S[2]
    
    S4 = S[3]
    
    S = [S1, S2, S3, S4]
    
    total_capacity = 0
    
    q_optimal_1 = sigma_one(noise_variance,S1)
    
    c1 = np.log2(1 + (1/noise_variance)* np.square(S1) * q_optimal_1[0])
    
    q_optimal_2 = sigma_two(noise_variance,S1,S2,q_optimal_1)
    
    c2 =0
    
    for nn in range(len(q_optimal_2)):
        
        c2 = c2 + np.log2(1 + (1/noise_variance)* np.square(S[nn])*q_optimal_2[nn])
        
    q_optimal_3 = sigma_three(noise_variance,S1,S2,S3,q_optimal_2)
    
    c3 =0
    
    for pp in range(len(q_optimal_3)):
        
        c3 = c3 + np.log2(1 + (1/noise_variance)* np.square(S[pp])*q_optimal_3[pp])
        
    q_optimal_4 = sigma_four(noise_variance,S1,S2,S3,S4,q_optimal_3)
    
    c4 = 0
    
    for ss in range(len(q_optimal_4)):
        
        c4 = c4 + np.log2(1 + (1/noise_variance)* np.square(S[ss])*q_optimal_4[ss])
    
    c = [c1, c2, c3, c4]
    
    c = max(c)
    
    return c

# %%
def joint_svd_with_csit():
    
    for jj in range(len(eb_no_db)):
        
        snr = 10**(eb_no_db[jj] / 10)
        
        nTx = 4
        
        nRx = 4
        
        Rz = (1/snr) * np.eye(nRx)
        
        Rz_inverse = np.linalg.inv(Rz )
        
        noise_variance = (1/snr)
        
        total_capacity = 0
        
        for ii in range(N):
            
            H = (1/np.sqrt(2)) * (np.random.randn(nTx,nRx) + 1j * np.random.randn(nTx,nRx))
            
            U,S,Vh = np.linalg.svd(H)
            
            capacity_values = capacity(noise_variance,S)
            
            total_capacity = total_capacity + capacity_values
            
        jointSvdWithCsit[jj] = total_capacity / N
    
    return jointSvdWithCsit

# %%
rxmf = Rx_MF ()

rxmf_reduced_svd=RxMF_R_SVD()

rxzf = Rx_ZF()

rxzf_reduced_svd = RxZF_R_SVD()

rxmmse =Rx_MMSE ()

rxzf_reduced_svd =RxMMSE_R_SVD()

svd_with_csit = joint_svd_with_csit()

plt.figure()

plt.figure(figsize=(10, 10))

plt.plot(eb_no_db, rxmf, 'k^-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/o csit RxMF)(EPA_P)')

plt.plot(eb_no_db, rxmf_reduced_svd, 'm>-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/o csit RxMF)(SVD-P)')

plt.plot(eb_no_db, rxzf, 'rv-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/o csit RxZF)(EPA-P)')

plt.plot(eb_no_db, rxzf_reduced_svd, 'gv-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/o csit RxZF)(SVD_P)')

plt.plot(eb_no_db, rxmmse, 'c*-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/o csit RxMMSE)')

plt.plot(eb_no_db, rxzf_reduced_svd, 'y*-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/o csit RxMMSE)(EPA-SVD)')

plt.plot(eb_no_db, svd_with_csit, 'mo-', linewidth=2, markersize=8, label='nTx=4 nRx=4 (mimo w/ csit)')

plt.grid(True)
plt.legend()
plt.xlabel('Eb/No, dB')
plt.ylabel('Average Capacity')
plt.title('SNR-dB')
plt.show()
